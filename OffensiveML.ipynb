# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,VotingClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import warnings
warnings.filterwarnings('ignore')

# %%
class MultilingualOffensiveLanguageDetector:
    def __init__(self):
        self.models = {}
        self.pipelines = {}
        self.languages = ['kannada', 'malayalam', 'tulu', 'tamil']
        self.predictions = {}
        self.data = {}
        self.evaluation_results = {}

    def preprocess_text(self, text):
        if pd.isna(text):
            return ""
        text = str(text).lower()
        text = re.sub(r'\s+', ' ', text)
        text = re.sub(r'[^\w\s\u0B80-\u0BFF\u0C00-\u0C7F\u0C80-\u0CFF\u0D00-\u0D7F]', ' ', text)
        return text.strip()

    def load_data(self, file_paths):
        for lang in self.languages:
            if lang in file_paths:
                print(f"Loading {lang} data...")
                train_df = pd.read_csv(file_paths[lang]['train'])
                val_df = pd.read_csv(file_paths[lang]['val'])
                test_df = pd.read_csv(file_paths[lang]['test'])
                if lang == 'tulu':
                    if 'Label' in train_df.columns:
                        train_df = train_df.rename(columns={'Label': 'Labels'})
                    if 'Label' in val_df.columns:
                        val_df = val_df.rename(columns={'Label': 'Labels'})
                self.data[lang] = {'train': train_df, 'val': val_df, 'test': test_df}
                print(f"{lang} - Train: {train_df.shape}, Val: {val_df.shape}, Test: {test_df.shape}")
                if 'Labels' in train_df.columns:
                    print(train_df['Labels'].value_counts())

# %%
def analyze_labels(self, lang):
    if lang in self.data:
        train_labels = self.data[lang]['train']['Labels']
        val_labels = self.data[lang]['val']['Labels']
        print(f"\n{lang.upper()} - Train Label Dist:\n{train_labels.value_counts()}")
        print(f"\n{lang.upper()} - Val Label Dist:\n{val_labels.value_counts()}")
        return train_labels.value_counts(), val_labels.value_counts()
    return None, None

def prepare_data(self, lang):
    train_texts = self.data[lang]['train']['Text'].apply(self.preprocess_text)
    train_labels = self.data[lang]['train']['Labels']
    val_texts = self.data[lang]['val']['Text'].apply(self.preprocess_text)
    val_labels = self.data[lang]['val']['Labels']
    test_texts = self.data[lang]['test']['Text'].apply(self.preprocess_text)
    test_ids = self.data[lang]['test']['ID']
    return train_texts, train_labels, val_texts, val_labels, test_texts, test_ids

MultilingualOffensiveLanguageDetector.analyze_labels = analyze_labels
MultilingualOffensiveLanguageDetector.prepare_data = prepare_data

# %%
def create_model_pipeline(self, model_type='logistic'):
    if model_type == 'logistic':
        classifier = LogisticRegression(random_state=42, max_iter=2000, multi_class='ovr', class_weight='balanced')
    elif model_type == 'svm':
        classifier = SVC(random_state=42, probability=True, class_weight='balanced', kernel='linear')
    elif model_type == 'random_forest':
        classifier = RandomForestClassifier(random_state=42, n_estimators=200, class_weight='balanced', max_depth=10)
    elif model_type == 'naive_bayes':
        classifier = MultinomialNB(alpha=0.1)
    else:
        classifier = LogisticRegression(random_state=42, max_iter=2000, multi_class='ovr', class_weight='balanced')

    pipeline = Pipeline([
        ('tfidf', TfidfVectorizer(max_features=15000, ngram_range=(1, 3), min_df=2, max_df=0.95, sublinear_tf=True)),
        ('classifier', classifier)
    ])
    return pipeline

MultilingualOffensiveLanguageDetector.create_model_pipeline = create_model_pipeline

# %%
def train_and_evaluate_model(self, lang, model_type='logistic'):
    train_texts, train_labels, val_texts, val_labels, test_texts, test_ids = self.prepare_data(lang)
    pipeline = self.create_model_pipeline(model_type)
    print(f"Training {model_type} for {lang}...")
    pipeline.fit(train_texts, train_labels)

    self.pipelines[f"{lang}_{model_type}"] = pipeline
    val_pred = pipeline.predict(val_texts)

    macro_f1 = f1_score(val_labels, val_pred, average='macro')
    accuracy = accuracy_score(val_labels, val_pred)

    self.evaluation_results[f"{lang}_{model_type}"] = {
        'macro_f1': macro_f1,
        'accuracy': accuracy,
        'val_true': val_labels,
        'val_pred': val_pred,
        'classification_report': classification_report(val_labels, val_pred)
    }

    test_pred = pipeline.predict(test_texts)
    self.predictions[f"{lang}_{model_type}"] = {'ids': test_ids, 'predictions': test_pred}

    print(f"{lang} - {model_type} | F1: {macro_f1:.4f}, Acc: {accuracy:.4f}")
    return pipeline

def train_all_languages(self, model_types=['logistic', 'random_forest', 'svm', 'naive_bayes']):
    for lang in self.languages:
        if lang in self.data:
            for model_type in model_types:
                self.train_and_evaluate_model(lang, model_type)

MultilingualOffensiveLanguageDetector.train_and_evaluate_model = train_and_evaluate_model
MultilingualOffensiveLanguageDetector.train_all_languages = train_all_languages

# %%
def train_voting_ensemble(self, lang, model_types=['logistic','random_forest','svm','naive_bayes']):
    train_texts, train_labels, val_texts, val_labels, test_texts, test_ids = self.prepare_data(lang)
    estimators = [(m, self.pipelines[f"{lang}_{m}"]) for m in model_types if f"{lang}_{m}" in self.pipelines]
    if not estimators: return None
    ensemble = VotingClassifier(estimators=estimators, voting='hard')
    ensemble.fit(train_texts, train_labels)

    val_pred = ensemble.predict(val_texts)
    macro_f1 = f1_score(val_labels, val_pred, average='macro')
    accuracy = accuracy_score(val_labels, val_pred)

    self.evaluation_results[f"{lang}_voting_ensemble"] = {
        'macro_f1': macro_f1,
        'accuracy': accuracy,
        'val_true': val_labels,
        'val_pred': val_pred,
        'classification_report': classification_report(val_labels, val_pred, digits=4)
    }

    test_pred = ensemble.predict(test_texts)
    self.predictions[f"{lang}_voting_ensemble"] = {'ids': test_ids, 'predictions': test_pred}
    self.pipelines[f"{lang}_voting_ensemble"] = ensemble

    print(f"{lang} Voting Ensemble | F1: {macro_f1:.4f}, Acc: {accuracy:.4f}")
    print(self.evaluation_results[f"{lang}_voting_ensemble"]["classification_report"])
    return ensemble


def train_weighted_ensemble(self, lang, model_types=['logistic','random_forest','svm','naive_bayes']):
    _, _, val_texts, val_labels, test_texts, test_ids = self.prepare_data(lang)
    preds_val, preds_test, weights = [], [], []

    # Collect predictions and weights from available models
    for m in model_types:
        key = f"{lang}_{m}"
        if key in self.evaluation_results:
            preds_val.append(self.evaluation_results[key]['val_pred'])
            preds_test.append(self.predictions[key]['predictions'])
            weights.append(self.evaluation_results[key]['macro_f1'])

    if not weights:
        print(f"No models available to create weighted ensemble for {lang}")
        return None

    weights = np.array(weights) / np.sum(weights)
    preds_val, preds_test = np.array(preds_val), np.array(preds_test)

    def weighted_vote(preds, weights):
        out = []
        for i in range(preds.shape[1]):
            votes = {}
            for j, label in enumerate(preds[:, i]):
                votes[label] = votes.get(label, 0) + weights[j]
            out.append(max(votes, key=votes.get))
        return np.array(out)

    val_final = weighted_vote(preds_val, weights)
    test_final = weighted_vote(preds_test, weights)

    macro_f1 = f1_score(val_labels, val_final, average='macro')
    accuracy = accuracy_score(val_labels, val_final)

    self.evaluation_results[f"{lang}_weighted_ensemble"] = {
        'macro_f1': macro_f1,
        'accuracy': accuracy,
        'val_true': val_labels,
        'val_pred': val_final,
        'classification_report': classification_report(val_labels, val_final, digits=4)
    }

    self.predictions[f"{lang}_weighted_ensemble"] = {'ids': test_ids, 'predictions': test_final}

    print(f"{lang} Weighted Ensemble | F1: {macro_f1:.4f}, Acc: {accuracy:.4f}")
    print("Classification Report (Validation):")
    print(self.evaluation_results[f"{lang}_weighted_ensemble"]['classification_report'])
    return test_final

MultilingualOffensiveLanguageDetector.train_weighted_ensemble = train_weighted_ensemble
MultilingualOffensiveLanguageDetector.train_voting_ensemble = train_voting_ensemble

# %%
def evaluate_on_test_with_labels(self, lang, model_type, test_file_paths):
    key_pipeline = f"{lang}_{model_type}"

    # Load test data
    df_test = pd.read_csv(test_file_paths[lang])
    label_col = "Labels" if "Labels" in df_test.columns else "Label"
    test_labels = df_test[label_col]
    test_texts = df_test['Text'].apply(self.preprocess_text)

    # Check if it's a pipeline model
    if key_pipeline in self.pipelines:
        pred = self.pipelines[key_pipeline].predict(test_texts)
    # Check if predictions already exist (weighted ensemble)
    elif key_pipeline in self.predictions:
        pred = self.predictions[key_pipeline]['predictions']
    else:
        print(f"No trained model or predictions found for {lang}-{model_type}")
        return None

    # Compute metrics
    macro_f1 = f1_score(test_labels, pred, average='macro')
    acc = accuracy_score(test_labels, pred)
    cls_report = classification_report(test_labels, pred, digits=4)

    # Print
    print(f"\n{lang.upper()}-{model_type.upper()} | Test F1={macro_f1:.4f}, Acc={acc:.4f}")
    print("Classification Report (Test):")
    print(cls_report)

    # Save results
    self.evaluation_results[f"{lang}_{model_type}_test"] = {
        'macro_f1': macro_f1,
        'accuracy': acc,
        'true': test_labels,
        'pred': pred,
        'classification_report': cls_report
    }

    return pred

MultilingualOffensiveLanguageDetector.evaluate_on_test_with_labels = evaluate_on_test_with_labels

# %%
def error_analysis_on_test(self, lang, model_type, test_file_paths):
    if lang not in test_file_paths:
        print(f"No test file for {lang}")
        return

    df_test = pd.read_csv(test_file_paths[lang])
    label_col = "Labels" if "Labels" in df_test.columns else "Label"

    key = f"{lang}_{model_type}"
    if key not in self.predictions:
        print(f"No predictions found for {key}")
        return

    preds = self.predictions[key]['predictions']

    df_test["Predicted_Label"] = preds
    df_test["True_Label"] = df_test[label_col]

    misclassified_df = df_test[df_test["True_Label"] != df_test["Predicted_Label"]]
    os.makedirs("error_analysis", exist_ok=True)
    out_csv = f"error_analysis/{lang}_{model_type}_misclassified.csv"
    misclassified_df.to_csv(out_csv, index=False)

    cm = confusion_matrix(df_test["True_Label"], preds, labels=sorted(df_test[label_col].unique()))
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap="Blues",
                xticklabels=sorted(df_test[label_col].unique()),
                yticklabels=sorted(df_test[label_col].unique()))
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"Confusion Matrix - {lang}-{model_type}")
    out_png = f"error_analysis/{lang}_{model_type}_confusion_matrix.png"
    plt.savefig(out_png, dpi=300, bbox_inches="tight")
    plt.close()

    print(f"[{lang}-{model_type}] Errors saved → {out_csv} ({len(misclassified_df)} rows)")
    print(f"[{lang}-{model_type}] Confusion Matrix saved → {out_png}")

MultilingualOffensiveLanguageDetector.error_analysis_on_test = error_analysis_on_test

# %%
# Initialize detector
detector = MultilingualOffensiveLanguageDetector()

# Dataset paths
file_paths = {
    'kannada': {
        'train': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/kannada_offensive_train.csv',
        'val': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/kannada_offensive_dev.csv',
        'test': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/kannada_offensive_test_without_labels.csv'
    },
    'malayalam': {
        'train': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/mal_full_offensive_train.csv',
        'val': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/mal_full_offensive_dev.csv',
        'test': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/mal_offensive_test_without_labels.csv'
    },
    'tulu': {
        'train': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/Tulu_offensive_train.csv',
        'val': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/Tulu_offensive_dev.csv',
        'test': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/Tulu_test_data_without_label.csv'
    },
    'tamil': {
        'train': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/tamil_offensive_full_train.csv',
        'val': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/tamil_offensive_full_dev.csv',
        'test': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/tamil_offensive_test_without_labels.csv'
    }
}

test_file_paths = {
    'kannada': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/kannada_offensive_test_with_labels.csv',
    'malayalam': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/mal_offensive_test_with_labels.csv',
    'tulu': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/tulu_offensive_test_with_labels.csv',
    'tamil': '/content/drive/MyDrive/FIRE-2025/Offensive Language Identification/tamil_offensive_full_test_with_labels.csv'
}

# Load data and train
detector.load_data(file_paths)
detector.train_all_languages(['logistic','random_forest','svm','naive_bayes'])

# Ensembles
for lang in detector.languages:
    if lang in detector.data:
        detector.train_voting_ensemble(lang)
        detector.train_weighted_ensemble(lang)

# Evaluation + Error Analysis
for lang in detector.languages:
    for model in ['logistic','random_forest','svm','naive_bayes','voting_ensemble','weighted_ensemble']:
        detector.evaluate_on_test_with_labels(lang, model, test_file_paths=test_file_paths)
        detector.error_analysis_on_test(lang, model, test_file_paths=test_file_paths)
# Out:
# Loading kannada data...
# kannada - Train: (6217, 2), Val: (777, 2), Test: (778, 2)
# Labels
# Not_offensive                           3544
# not-Kannada                             1522
# Offensive_Targeted_Insult_Individual     487
# Offensive_Targeted_Insult_Group          329
# Offensive_Untargetede                    212
# Offensive_Targeted_Insult_Other          123
# Name: count, dtype: int64
# Loading malayalam data...
# malayalam - Train: (16010, 2), Val: (1999, 2), Test: (2001, 2)
# Labels
# Not_offensive                           14153
# not-malayalam                            1287
# Offensive_Targeted_Insult_Individual      239
# Offensive_Untargetede                     191
# Offensive_Targeted_Insult_Group           140
# Name: count, dtype: int64
# Loading tulu data...
# tulu - Train: (2692, 2), Val: (577, 2), Test: (576, 2)
# Labels
# not offensive           1261
# not tulu                 726
# offensive untargeted     462
# offensive targeted       243
# Name: count, dtype: int64
# Loading tamil data...
# tamil - Train: (35139, 2), Val: (4388, 2), Test: (4392, 2)
# Labels
# Not_offensive                           25425
# Offensive_Untargetede                    2906
# Offensive_Targeted_Insult_Group          2557
# Offensive_Targeted_Insult_Individual     2343
# not-Tamil                                1454
# Offensive_Targeted_Insult_Other           454
# Name: count, dtype: int64
# Training logistic for kannada...
# kannada - logistic | F1: 0.4158, Acc: 0.6409
# Training random_forest for kannada...
# kannada - random_forest | F1: 0.3683, Acc: 0.4916
# Training svm for kannada...
# kannada - svm | F1: 0.4152, Acc: 0.6100
# Training naive_bayes for kannada...
# kannada - naive_bayes | F1: 0.3949, Acc: 0.6950
# Training logistic for malayalam...
# malayalam - logistic | F1: 0.6009, Acc: 0.9065
# Training random_forest for malayalam...
# malayalam - random_forest | F1: 0.3847, Acc: 0.7744
# Training svm for malayalam...
# malayalam - svm | F1: 0.6065, Acc: 0.9135
# Training naive_bayes for malayalam...
# malayalam - naive_bayes | F1: 0.5060, Acc: 0.9385
# Training logistic for tulu...
# tulu - logistic | F1: 0.7622, Acc: 0.7972
# Training random_forest for tulu...
# tulu - random_forest | F1: 0.6568, Acc: 0.7054
# Training svm for tulu...
# tulu - svm | F1: 0.7798, Acc: 0.8024
# Training naive_bayes for tulu...
# tulu - naive_bayes | F1: 0.7569, Acc: 0.8024
# Training logistic for tamil...
# tamil - logistic | F1: 0.4422, Acc: 0.6825
# Training random_forest for tamil...
# tamil - random_forest | F1: 0.2983, Acc: 0.3936
# Training svm for tamil...
# tamil - svm | F1: 0.4179, Acc: 0.6408
# Training naive_bayes for tamil...
# tamil - naive_bayes | F1: 0.4301, Acc: 0.7632
# kannada Voting Ensemble | F1: 0.4415, Acc: 0.6628
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7690    0.7113    0.7390       426
#      Offensive_Targeted_Insult_Group     0.4000    0.3111    0.3500        45
# Offensive_Targeted_Insult_Individual     0.5606    0.5606    0.5606        66
#      Offensive_Targeted_Insult_Other     0.1818    0.1250    0.1481        16
#                Offensive_Untargetede     0.1905    0.1212    0.1481        33
#                          not-Kannada     0.6200    0.8115    0.7029       191
#
#                             accuracy                         0.6628       777
#                            macro avg     0.4537    0.4401    0.4415       777
#                         weighted avg     0.6567    0.6628    0.6552       777
#
# kannada Weighted Ensemble | F1: 0.4396, Acc: 0.6551
# Classification Report (Validation):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7802    0.6831    0.7284       426
#      Offensive_Targeted_Insult_Group     0.3750    0.3333    0.3529        45
# Offensive_Targeted_Insult_Individual     0.5735    0.5909    0.5821        66
#      Offensive_Targeted_Insult_Other     0.1333    0.1250    0.1290        16
#                Offensive_Untargetede     0.1600    0.1212    0.1379        33
#                          not-Kannada     0.6172    0.8272    0.7069       191
#
#                             accuracy                         0.6551       777
#                            macro avg     0.4399    0.4468    0.4396       777
#                         weighted avg     0.6594    0.6551    0.6515       777
#
# malayalam Voting Ensemble | F1: 0.6229, Acc: 0.9335
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9666    0.9612    0.9639      1779
#      Offensive_Targeted_Insult_Group     0.5000    0.4615    0.4800        13
# Offensive_Targeted_Insult_Individual     0.6250    0.4167    0.5000        24
#                Offensive_Untargetede     0.3600    0.4500    0.4000        20
#                        not-malayalam     0.7401    0.8037    0.7706       163
#
#                             accuracy                         0.9335      1999
#                            macro avg     0.6384    0.6186    0.6229      1999
#                         weighted avg     0.9350    0.9335    0.9338      1999
#
# malayalam Weighted Ensemble | F1: 0.6411, Acc: 0.9265
# Classification Report (Validation):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9789    0.9404    0.9593      1779
#      Offensive_Targeted_Insult_Group     0.4211    0.6154    0.5000        13
# Offensive_Targeted_Insult_Individual     0.4444    0.5000    0.4706        24
#                Offensive_Untargetede     0.4286    0.6000    0.5000        20
#                        not-malayalam     0.6806    0.9018    0.7757       163
#
#                             accuracy                         0.9265      1999
#                            macro avg     0.5907    0.7115    0.6411      1999
#                         weighted avg     0.9391    0.9265    0.9309      1999
#
# tulu Voting Ensemble | F1: 0.7628, Acc: 0.8076
#                       precision    recall  f1-score   support
#
#        not offensive     0.8095    0.8815    0.8440       270
#             not tulu     0.8299    0.7821    0.8053       156
#   offensive targeted     0.7105    0.5192    0.6000        52
# offensive untargeted     0.8061    0.7980    0.8020        99
#
#             accuracy                         0.8076       577
#            macro avg     0.7890    0.7452    0.7628       577
#         weighted avg     0.8055    0.8076    0.8043       577
#
# tulu Weighted Ensemble | F1: 0.7676, Acc: 0.8007
# Classification Report (Validation):
#                       precision    recall  f1-score   support
#
#        not offensive     0.8242    0.8333    0.8287       270
#             not tulu     0.7875    0.8077    0.7975       156
#   offensive targeted     0.7143    0.5769    0.6383        52
# offensive untargeted     0.7941    0.8182    0.8060        99
#
#             accuracy                         0.8007       577
#            macro avg     0.7800    0.7590    0.7676       577
#         weighted avg     0.7992    0.8007    0.7992       577
#
# tamil Voting Ensemble | F1: 0.4430, Acc: 0.6994
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.8936    0.7914    0.8394      3193
#      Offensive_Targeted_Insult_Group     0.2808    0.4407    0.3430       295
# Offensive_Targeted_Insult_Individual     0.3280    0.4007    0.3607       307
#      Offensive_Targeted_Insult_Other     0.0435    0.0308    0.0360        65
#                Offensive_Untargetede     0.3299    0.4466    0.3795       356
#                            not-Tamil     0.6598    0.7442    0.6995       172
#
#                             accuracy                         0.6994      4388
#                            macro avg     0.4226    0.4757    0.4430      4388
#                         weighted avg     0.7453    0.6994    0.7178      4388
#
# tamil Weighted Ensemble | F1: 0.4444, Acc: 0.6921
# Classification Report (Validation):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9043    0.7758    0.8351      3193
#      Offensive_Targeted_Insult_Group     0.2727    0.4373    0.3359       295
# Offensive_Targeted_Insult_Individual     0.3211    0.4267    0.3664       307
#      Offensive_Targeted_Insult_Other     0.0508    0.0462    0.0484        65
#                Offensive_Untargetede     0.3300    0.4691    0.3875       356
#                            not-Tamil     0.6404    0.7558    0.6933       172
#
#                             accuracy                         0.6921      4388
#                            macro avg     0.4199    0.4851    0.4444      4388
#                         weighted avg     0.7515    0.6921    0.7152      4388
#
#
# KANNADA-LOGISTIC | Test F1=0.4132, Acc=0.6414
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.8040    0.6534    0.7209       427
#      Offensive_Targeted_Insult_Group     0.2857    0.3182    0.3011        44
# Offensive_Targeted_Insult_Individual     0.5974    0.6133    0.6053        75
#      Offensive_Targeted_Insult_Other     0.0000    0.0000    0.0000        14
#                Offensive_Untargetede     0.1471    0.1515    0.1493        33
#                          not-Kannada     0.6055    0.8378    0.7029       185
#
#                             accuracy                         0.6414       778
#                            macro avg     0.4066    0.4290    0.4132       778
#                         weighted avg     0.6652    0.6414    0.6445       778
#
# [kannada-logistic] Errors saved → error_analysis/kannada_logistic_misclassified.csv (279 rows)
# [kannada-logistic] Confusion Matrix saved → error_analysis/kannada_logistic_confusion_matrix.png
#
# KANNADA-RANDOM_FOREST | Test F1=0.3779, Acc=0.4859
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7944    0.3349    0.4712       427
#      Offensive_Targeted_Insult_Group     0.1944    0.3182    0.2414        44
# Offensive_Targeted_Insult_Individual     0.7333    0.5867    0.6519        75
#      Offensive_Targeted_Insult_Other     0.1429    0.2143    0.1714        14
#                Offensive_Untargetede     0.1429    0.1818    0.1600        33
#                          not-Kannada     0.4169    0.9081    0.5714       185
#
#                             accuracy                         0.4859       778
#                            macro avg     0.4041    0.4240    0.3779       778
#                         weighted avg     0.6255    0.4859    0.4808       778
#
# [kannada-random_forest] Errors saved → error_analysis/kannada_random_forest_misclassified.csv (400 rows)
# [kannada-random_forest] Confusion Matrix saved → error_analysis/kannada_random_forest_confusion_matrix.png
#
# KANNADA-SVM | Test F1=0.4416, Acc=0.6285
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.8301    0.5948    0.6930       427
#      Offensive_Targeted_Insult_Group     0.3333    0.3864    0.3579        44
# Offensive_Targeted_Insult_Individual     0.5488    0.6000    0.5732        75
#      Offensive_Targeted_Insult_Other     0.2000    0.2143    0.2069        14
#                Offensive_Untargetede     0.1212    0.1212    0.1212        33
#                          not-Kannada     0.5704    0.8973    0.6975       185
#
#                             accuracy                         0.6285       778
#                            macro avg     0.4340    0.4690    0.4416       778
#                         weighted avg     0.6717    0.6285    0.6306       778
#
# [kannada-svm] Errors saved → error_analysis/kannada_svm_misclassified.csv (289 rows)
# [kannada-svm] Confusion Matrix saved → error_analysis/kannada_svm_confusion_matrix.png
#
# KANNADA-NAIVE_BAYES | Test F1=0.4022, Acc=0.6954
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7312    0.8220    0.7740       427
#      Offensive_Targeted_Insult_Group     0.3750    0.1364    0.2000        44
# Offensive_Targeted_Insult_Individual     0.6818    0.6000    0.6383        75
#      Offensive_Targeted_Insult_Other     0.0000    0.0000    0.0000        14
#                Offensive_Untargetede     0.4000    0.0606    0.1053        33
#                          not-Kannada     0.6555    0.7405    0.6954       185
#
#                             accuracy                         0.6954       778
#                            macro avg     0.4739    0.3933    0.4022       778
#                         weighted avg     0.6611    0.6954    0.6675       778
#
# [kannada-naive_bayes] Errors saved → error_analysis/kannada_naive_bayes_misclassified.csv (237 rows)
# [kannada-naive_bayes] Confusion Matrix saved → error_analysis/kannada_naive_bayes_confusion_matrix.png
#
# KANNADA-VOTING_ENSEMBLE | Test F1=0.4208, Acc=0.6645
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7895    0.7026    0.7435       427
#      Offensive_Targeted_Insult_Group     0.3514    0.2955    0.3210        44
# Offensive_Targeted_Insult_Individual     0.6250    0.6000    0.6122        75
#      Offensive_Targeted_Insult_Other     0.0000    0.0000    0.0000        14
#                Offensive_Untargetede     0.1905    0.1212    0.1481        33
#                          not-Kannada     0.6008    0.8378    0.6998       185
#
#                             accuracy                         0.6645       778
#                            macro avg     0.4262    0.4262    0.4208       778
#                         weighted avg     0.6644    0.6645    0.6579       778
#
# [kannada-voting_ensemble] Errors saved → error_analysis/kannada_voting_ensemble_misclassified.csv (261 rows)
# [kannada-voting_ensemble] Confusion Matrix saved → error_analysis/kannada_voting_ensemble_confusion_matrix.png
#
# KANNADA-WEIGHTED_ENSEMBLE | Test F1=0.4137, Acc=0.6517
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7961    0.6768    0.7316       427
#      Offensive_Targeted_Insult_Group     0.3333    0.3182    0.3256        44
# Offensive_Targeted_Insult_Individual     0.5844    0.6000    0.5921        75
#      Offensive_Targeted_Insult_Other     0.0000    0.0000    0.0000        14
#                Offensive_Untargetede     0.1481    0.1212    0.1333        33
#                          not-Kannada     0.6008    0.8378    0.6998       185
#
#                             accuracy                         0.6517       778
#                            macro avg     0.4105    0.4257    0.4137       778
#                         weighted avg     0.6613    0.6517    0.6491       778
#
# [kannada-weighted_ensemble] Errors saved → error_analysis/kannada_weighted_ensemble_misclassified.csv (271 rows)
# [kannada-weighted_ensemble] Confusion Matrix saved → error_analysis/kannada_weighted_ensemble_confusion_matrix.png
#
# MALAYALAM-LOGISTIC | Test F1=0.6623, Acc=0.9080
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9830    0.9173    0.9490      1765
#      Offensive_Targeted_Insult_Group     0.4000    0.4348    0.4167        23
# Offensive_Targeted_Insult_Individual     0.5556    0.7407    0.6349        27
#                Offensive_Untargetede     0.4528    0.8276    0.5854        29
#                        not-malayalam     0.6000    0.9172    0.7254       157
#
#                             accuracy                         0.9080      2001
#                            macro avg     0.5983    0.7675    0.6623      2001
#                         weighted avg     0.9328    0.9080    0.9158      2001
#
# [malayalam-logistic] Errors saved → error_analysis/malayalam_logistic_misclassified.csv (184 rows)
# [malayalam-logistic] Confusion Matrix saved → error_analysis/malayalam_logistic_confusion_matrix.png
#
# MALAYALAM-RANDOM_FOREST | Test F1=0.4360, Acc=0.7771
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9530    0.7926    0.8655      1765
#      Offensive_Targeted_Insult_Group     0.2800    0.3043    0.2917        23
# Offensive_Targeted_Insult_Individual     0.1538    0.3704    0.2174        27
#                Offensive_Untargetede     0.2632    0.5172    0.3488        29
#                        not-malayalam     0.3212    0.7898    0.4567       157
#
#                             accuracy                         0.7771      2001
#                            macro avg     0.3942    0.5549    0.4360      2001
#                         weighted avg     0.8749    0.7771    0.8106      2001
#
# [malayalam-random_forest] Errors saved → error_analysis/malayalam_random_forest_misclassified.csv (446 rows)
# [malayalam-random_forest] Confusion Matrix saved → error_analysis/malayalam_random_forest_confusion_matrix.png
#
# MALAYALAM-SVM | Test F1=0.6754, Acc=0.9155
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9814    0.9263    0.9531      1765
#      Offensive_Targeted_Insult_Group     0.4615    0.5217    0.4898        23
# Offensive_Targeted_Insult_Individual     0.4865    0.6667    0.5625        27
#                Offensive_Untargetede     0.5111    0.7931    0.6216        29
#                        not-malayalam     0.6344    0.9172    0.7500       157
#
#                             accuracy                         0.9155      2001
#                            macro avg     0.6150    0.7650    0.6754      2001
#                         weighted avg     0.9347    0.9155    0.9217      2001
#
# [malayalam-svm] Errors saved → error_analysis/malayalam_svm_misclassified.csv (169 rows)
# [malayalam-svm] Confusion Matrix saved → error_analysis/malayalam_svm_confusion_matrix.png
#
# MALAYALAM-NAIVE_BAYES | Test F1=0.5014, Acc=0.9335
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9421    0.9864    0.9637      1765
#      Offensive_Targeted_Insult_Group     0.8000    0.1739    0.2857        23
# Offensive_Targeted_Insult_Individual     1.0000    0.1111    0.2000        27
#                Offensive_Untargetede     0.7143    0.1724    0.2778        29
#                        not-malayalam     0.8333    0.7325    0.7797       157
#
#                             accuracy                         0.9335      2001
#                            macro avg     0.8579    0.4353    0.5014      2001
#                         weighted avg     0.9294    0.9335    0.9213      2001
#
# [malayalam-naive_bayes] Errors saved → error_analysis/malayalam_naive_bayes_misclassified.csv (133 rows)
# [malayalam-naive_bayes] Confusion Matrix saved → error_analysis/malayalam_naive_bayes_confusion_matrix.png
#
# MALAYALAM-VOTING_ENSEMBLE | Test F1=0.6444, Acc=0.9275
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9635    0.9569    0.9602      1765
#      Offensive_Targeted_Insult_Group     0.6154    0.3478    0.4444        23
# Offensive_Targeted_Insult_Individual     0.8462    0.4074    0.5500        27
#                Offensive_Untargetede     0.4571    0.5517    0.5000        29
#                        not-malayalam     0.7059    0.8408    0.7674       157
#
#                             accuracy                         0.9275      2001
#                            macro avg     0.7176    0.6209    0.6444      2001
#                         weighted avg     0.9304    0.9275    0.9269      2001
#
# [malayalam-voting_ensemble] Errors saved → error_analysis/malayalam_voting_ensemble_misclassified.csv (145 rows)
# [malayalam-voting_ensemble] Confusion Matrix saved → error_analysis/malayalam_voting_ensemble_confusion_matrix.png
#
# MALAYALAM-WEIGHTED_ENSEMBLE | Test F1=0.6921, Acc=0.9245
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9799    0.9382    0.9586      1765
#      Offensive_Targeted_Insult_Group     0.4545    0.4348    0.4444        23
# Offensive_Targeted_Insult_Individual     0.6552    0.7037    0.6786        27
#                Offensive_Untargetede     0.5000    0.7931    0.6133        29
#                        not-malayalam     0.6636    0.9045    0.7655       157
#
#                             accuracy                         0.9245      2001
#                            macro avg     0.6506    0.7549    0.6921      2001
#                         weighted avg     0.9377    0.9245    0.9288      2001
#
# [malayalam-weighted_ensemble] Errors saved → error_analysis/malayalam_weighted_ensemble_misclassified.csv (151 rows)
# [malayalam-weighted_ensemble] Confusion Matrix saved → error_analysis/malayalam_weighted_ensemble_confusion_matrix.png
#
# TULU-LOGISTIC | Test F1=0.7800, Acc=0.8125
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#        not offensive     0.8388    0.8481    0.8435       270
#             not tulu     0.8153    0.8258    0.8205       155
#   offensive targeted     0.7442    0.6154    0.6737        52
# offensive untargeted     0.7670    0.7980    0.7822        99
#
#             accuracy                         0.8125       576
#            macro avg     0.7913    0.7718    0.7800       576
#         weighted avg     0.8116    0.8125    0.8114       576
#
# [tulu-logistic] Errors saved → error_analysis/tulu_logistic_misclassified.csv (108 rows)
# [tulu-logistic] Confusion Matrix saved → error_analysis/tulu_logistic_confusion_matrix.png
#
# TULU-RANDOM_FOREST | Test F1=0.6020, Acc=0.6823
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#        not offensive     0.6619    0.8556    0.7464       270
#             not tulu     0.7946    0.5742    0.6667       155
#   offensive targeted     0.6667    0.2692    0.3836        52
# offensive untargeted     0.6277    0.5960    0.6114        99
#
#             accuracy                         0.6823       576
#            macro avg     0.6877    0.5737    0.6020       576
#         weighted avg     0.6922    0.6823    0.6690       576
#
# [tulu-random_forest] Errors saved → error_analysis/tulu_random_forest_misclassified.csv (183 rows)
# [tulu-random_forest] Confusion Matrix saved → error_analysis/tulu_random_forest_confusion_matrix.png
#
# TULU-SVM | Test F1=0.7918, Acc=0.8090
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#        not offensive     0.8188    0.8370    0.8278       270
#             not tulu     0.8000    0.8000    0.8000       155
#   offensive targeted     0.7660    0.6923    0.7273        52
# offensive untargeted     0.8163    0.8081    0.8122        99
#
#             accuracy                         0.8090       576
#            macro avg     0.8003    0.7844    0.7918       576
#         weighted avg     0.8086    0.8090    0.8086       576
#
# [tulu-svm] Errors saved → error_analysis/tulu_svm_misclassified.csv (110 rows)
# [tulu-svm] Confusion Matrix saved → error_analysis/tulu_svm_confusion_matrix.png
#
# TULU-NAIVE_BAYES | Test F1=0.7404, Acc=0.7969
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#        not offensive     0.7729    0.9074    0.8348       270
#             not tulu     0.8451    0.7742    0.8081       155
#   offensive targeted     0.8148    0.4231    0.5570        52
# offensive untargeted     0.8000    0.7273    0.7619        99
#
#             accuracy                         0.7969       576
#            macro avg     0.8082    0.7080    0.7404       576
#         weighted avg     0.8007    0.7969    0.7900       576
#
# [tulu-naive_bayes] Errors saved → error_analysis/tulu_naive_bayes_misclassified.csv (117 rows)
# [tulu-naive_bayes] Confusion Matrix saved → error_analysis/tulu_naive_bayes_confusion_matrix.png
#
# TULU-VOTING_ENSEMBLE | Test F1=0.7629, Acc=0.8073
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#        not offensive     0.7903    0.9074    0.8448       270
#             not tulu     0.8593    0.7484    0.8000       155
#   offensive targeted     0.8125    0.5000    0.6190        52
# offensive untargeted     0.7879    0.7879    0.7879        99
#
#             accuracy                         0.8073       576
#            macro avg     0.8125    0.7359    0.7629       576
#         weighted avg     0.8105    0.8073    0.8026       576
#
# [tulu-voting_ensemble] Errors saved → error_analysis/tulu_voting_ensemble_misclassified.csv (111 rows)
# [tulu-voting_ensemble] Confusion Matrix saved → error_analysis/tulu_voting_ensemble_confusion_matrix.png
#
# TULU-WEIGHTED_ENSEMBLE | Test F1=0.7925, Acc=0.8247
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#        not offensive     0.8393    0.8704    0.8545       270
#             not tulu     0.8366    0.8258    0.8312       155
#   offensive targeted     0.7805    0.6154    0.6882        52
# offensive untargeted     0.7843    0.8081    0.7960        99
#
#             accuracy                         0.8247       576
#            macro avg     0.8102    0.7799    0.7925       576
#         weighted avg     0.8238    0.8247    0.8232       576
#
# [tulu-weighted_ensemble] Errors saved → error_analysis/tulu_weighted_ensemble_misclassified.csv (101 rows)
# [tulu-weighted_ensemble] Confusion Matrix saved → error_analysis/tulu_weighted_ensemble_confusion_matrix.png
#
# TAMIL-LOGISTIC | Test F1=0.4387, Acc=0.6835
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9138    0.7680    0.8346      3190
#      Offensive_Targeted_Insult_Group     0.2532    0.4062    0.3120       288
# Offensive_Targeted_Insult_Individual     0.3129    0.4381    0.3651       315
#      Offensive_Targeted_Insult_Other     0.0435    0.0423    0.0429        71
#                Offensive_Untargetede     0.3102    0.4620    0.3712       368
#                            not-Tamil     0.6492    0.7750    0.7066       160
#
#                             accuracy                         0.6835      4392
#                            macro avg     0.4138    0.4819    0.4387      4392
#                         weighted avg     0.7531    0.6835    0.7104      4392
#
# [tamil-logistic] Errors saved → error_analysis/tamil_logistic_misclassified.csv (1390 rows)
# [tamil-logistic] Confusion Matrix saved → error_analysis/tamil_logistic_confusion_matrix.png
#
# TAMIL-RANDOM_FOREST | Test F1=0.3145, Acc=0.4101
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9241    0.3931    0.5516      3190
#      Offensive_Targeted_Insult_Group     0.1571    0.3125    0.2091       288
# Offensive_Targeted_Insult_Individual     0.2279    0.2540    0.2402       315
#      Offensive_Targeted_Insult_Other     0.0417    0.0845    0.0558        71
#                Offensive_Untargetede     0.1488    0.7065    0.2459       368
#                            not-Tamil     0.5045    0.6937    0.5842       160
#
#                             accuracy                         0.4101      4392
#                            macro avg     0.3340    0.4074    0.3145      4392
#                         weighted avg     0.7294    0.4101    0.4743      4392
#
# [tamil-random_forest] Errors saved → error_analysis/tamil_random_forest_misclassified.csv (2591 rows)
# [tamil-random_forest] Confusion Matrix saved → error_analysis/tamil_random_forest_confusion_matrix.png
#
# TAMIL-SVM | Test F1=0.4236, Acc=0.6462
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9128    0.7150    0.8019      3190
#      Offensive_Targeted_Insult_Group     0.2262    0.4375    0.2982       288
# Offensive_Targeted_Insult_Individual     0.2897    0.4635    0.3565       315
#      Offensive_Targeted_Insult_Other     0.0658    0.0704    0.0680        71
#                Offensive_Untargetede     0.2852    0.4293    0.3427       368
#                            not-Tamil     0.6040    0.7625    0.6740       160
#
#                             accuracy                         0.6462      4392
#                            macro avg     0.3973    0.4797    0.4236      4392
#                         weighted avg     0.7455    0.6462    0.6819      4392
#
# [tamil-svm] Errors saved → error_analysis/tamil_svm_misclassified.csv (1554 rows)
# [tamil-svm] Confusion Matrix saved → error_analysis/tamil_svm_confusion_matrix.png
#
# TAMIL-NAIVE_BAYES | Test F1=0.4370, Acc=0.7602
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.8306    0.9251    0.8753      3190
#      Offensive_Targeted_Insult_Group     0.3835    0.2743    0.3198       288
# Offensive_Targeted_Insult_Individual     0.3953    0.2159    0.2793       315
#      Offensive_Targeted_Insult_Other     0.0000    0.0000    0.0000        71
#                Offensive_Untargetede     0.3855    0.3478    0.3657       368
#                            not-Tamil     0.8760    0.7063    0.7820       160
#
#                             accuracy                         0.7602      4392
#                            macro avg     0.4785    0.4116    0.4370      4392
#                         weighted avg     0.7210    0.7602    0.7359      4392
#
# [tamil-naive_bayes] Errors saved → error_analysis/tamil_naive_bayes_misclassified.csv (1053 rows)
# [tamil-naive_bayes] Confusion Matrix saved → error_analysis/tamil_naive_bayes_confusion_matrix.png
#
# TAMIL-VOTING_ENSEMBLE | Test F1=0.4525, Acc=0.6997
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.8951    0.7969    0.8431      3190
#      Offensive_Targeted_Insult_Group     0.2604    0.3924    0.3130       288
# Offensive_Targeted_Insult_Individual     0.3359    0.4159    0.3716       315
#      Offensive_Targeted_Insult_Other     0.0909    0.0563    0.0696        71
#                Offensive_Untargetede     0.3090    0.4375    0.3622       368
#                            not-Tamil     0.7485    0.7625    0.7554       160
#
#                             accuracy                         0.6997      4392
#                            macro avg     0.4400    0.4769    0.4525      4392
#                         weighted avg     0.7459    0.6997    0.7185      4392
#
# [tamil-voting_ensemble] Errors saved → error_analysis/tamil_voting_ensemble_misclassified.csv (1319 rows)
# [tamil-voting_ensemble] Confusion Matrix saved → error_analysis/tamil_voting_ensemble_confusion_matrix.png
#
# TAMIL-WEIGHTED_ENSEMBLE | Test F1=0.4481, Acc=0.6926
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9063    0.7824    0.8398      3190
#      Offensive_Targeted_Insult_Group     0.2551    0.3889    0.3081       288
# Offensive_Targeted_Insult_Individual     0.3309    0.4381    0.3770       315
#      Offensive_Targeted_Insult_Other     0.0741    0.0563    0.0640        71
#                Offensive_Untargetede     0.3055    0.4565    0.3660       368
#                            not-Tamil     0.6966    0.7750    0.7337       160
#
#                             accuracy                         0.6926      4392
#                            macro avg     0.4281    0.4829    0.4481      4392
#                         weighted avg     0.7509    0.6926    0.7157      4392
#
# [tamil-weighted_ensemble] Errors saved → error_analysis/tamil_weighted_ensemble_misclassified.csv (1350 rows)
# [tamil-weighted_ensemble] Confusion Matrix saved → error_analysis/tamil_weighted_ensemble_confusion_matrix.png

# %%
for lang in detector.languages:
    detector.train_voting_ensemble(lang)
    detector.train_weighted_ensemble(lang)
# Out:
# kannada Voting Ensemble | F1: 0.4415, Acc: 0.6628
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7690    0.7113    0.7390       426
#      Offensive_Targeted_Insult_Group     0.4000    0.3111    0.3500        45
# Offensive_Targeted_Insult_Individual     0.5606    0.5606    0.5606        66
#      Offensive_Targeted_Insult_Other     0.1818    0.1250    0.1481        16
#                Offensive_Untargetede     0.1905    0.1212    0.1481        33
#                          not-Kannada     0.6200    0.8115    0.7029       191
#
#                             accuracy                         0.6628       777
#                            macro avg     0.4537    0.4401    0.4415       777
#                         weighted avg     0.6567    0.6628    0.6552       777
#
# kannada Weighted Ensemble | F1: 0.4396, Acc: 0.6551
# Classification Report (Validation):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7802    0.6831    0.7284       426
#      Offensive_Targeted_Insult_Group     0.3750    0.3333    0.3529        45
# Offensive_Targeted_Insult_Individual     0.5735    0.5909    0.5821        66
#      Offensive_Targeted_Insult_Other     0.1333    0.1250    0.1290        16
#                Offensive_Untargetede     0.1600    0.1212    0.1379        33
#                          not-Kannada     0.6172    0.8272    0.7069       191
#
#                             accuracy                         0.6551       777
#                            macro avg     0.4399    0.4468    0.4396       777
#                         weighted avg     0.6594    0.6551    0.6515       777
#
# malayalam Voting Ensemble | F1: 0.6229, Acc: 0.9335
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9666    0.9612    0.9639      1779
#      Offensive_Targeted_Insult_Group     0.5000    0.4615    0.4800        13
# Offensive_Targeted_Insult_Individual     0.6250    0.4167    0.5000        24
#                Offensive_Untargetede     0.3600    0.4500    0.4000        20
#                        not-malayalam     0.7401    0.8037    0.7706       163
#
#                             accuracy                         0.9335      1999
#                            macro avg     0.6384    0.6186    0.6229      1999
#                         weighted avg     0.9350    0.9335    0.9338      1999
#
# malayalam Weighted Ensemble | F1: 0.6411, Acc: 0.9265
# Classification Report (Validation):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9789    0.9404    0.9593      1779
#      Offensive_Targeted_Insult_Group     0.4211    0.6154    0.5000        13
# Offensive_Targeted_Insult_Individual     0.4444    0.5000    0.4706        24
#                Offensive_Untargetede     0.4286    0.6000    0.5000        20
#                        not-malayalam     0.6806    0.9018    0.7757       163
#
#                             accuracy                         0.9265      1999
#                            macro avg     0.5907    0.7115    0.6411      1999
#                         weighted avg     0.9391    0.9265    0.9309      1999
#
# tulu Voting Ensemble | F1: 0.7628, Acc: 0.8076
#                       precision    recall  f1-score   support
#
#        not offensive     0.8095    0.8815    0.8440       270
#             not tulu     0.8299    0.7821    0.8053       156
#   offensive targeted     0.7105    0.5192    0.6000        52
# offensive untargeted     0.8061    0.7980    0.8020        99
#
#             accuracy                         0.8076       577
#            macro avg     0.7890    0.7452    0.7628       577
#         weighted avg     0.8055    0.8076    0.8043       577
#
# tulu Weighted Ensemble | F1: 0.7676, Acc: 0.8007
# Classification Report (Validation):
#                       precision    recall  f1-score   support
#
#        not offensive     0.8242    0.8333    0.8287       270
#             not tulu     0.7875    0.8077    0.7975       156
#   offensive targeted     0.7143    0.5769    0.6383        52
# offensive untargeted     0.7941    0.8182    0.8060        99
#
#             accuracy                         0.8007       577
#            macro avg     0.7800    0.7590    0.7676       577
#         weighted avg     0.7992    0.8007    0.7992       577
#
# tamil Voting Ensemble | F1: 0.4430, Acc: 0.6994
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.8936    0.7914    0.8394      3193
#      Offensive_Targeted_Insult_Group     0.2808    0.4407    0.3430       295
# Offensive_Targeted_Insult_Individual     0.3280    0.4007    0.3607       307
#      Offensive_Targeted_Insult_Other     0.0435    0.0308    0.0360        65
#                Offensive_Untargetede     0.3299    0.4466    0.3795       356
#                            not-Tamil     0.6598    0.7442    0.6995       172
#
#                             accuracy                         0.6994      4388
#                            macro avg     0.4226    0.4757    0.4430      4388
#                         weighted avg     0.7453    0.6994    0.7178      4388
#
# tamil Weighted Ensemble | F1: 0.4444, Acc: 0.6921
# Classification Report (Validation):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9043    0.7758    0.8351      3193
#      Offensive_Targeted_Insult_Group     0.2727    0.4373    0.3359       295
# Offensive_Targeted_Insult_Individual     0.3211    0.4267    0.3664       307
#      Offensive_Targeted_Insult_Other     0.0508    0.0462    0.0484        65
#                Offensive_Untargetede     0.3300    0.4691    0.3875       356
#                            not-Tamil     0.6404    0.7558    0.6933       172
#
#                             accuracy                         0.6921      4388
#                            macro avg     0.4199    0.4851    0.4444      4388
#                         weighted avg     0.7515    0.6921    0.7152      4388

# %%
for lang in detector.languages:
    for model in ['voting_ensemble','weighted_ensemble']:
        print(f"\n===== {lang.upper()} - {model.upper()} =====")
        detector.evaluate_on_test_with_labels(lang, model, test_file_paths=test_file_paths)
        detector.error_analysis_on_test(lang, model, test_file_paths=test_file_paths)
# Out:
# ===== KANNADA - VOTING_ENSEMBLE =====
#
# KANNADA-VOTING_ENSEMBLE | Test F1=0.4208, Acc=0.6645
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7895    0.7026    0.7435       427
#      Offensive_Targeted_Insult_Group     0.3514    0.2955    0.3210        44
# Offensive_Targeted_Insult_Individual     0.6250    0.6000    0.6122        75
#      Offensive_Targeted_Insult_Other     0.0000    0.0000    0.0000        14
#                Offensive_Untargetede     0.1905    0.1212    0.1481        33
#                          not-Kannada     0.6008    0.8378    0.6998       185
#
#                             accuracy                         0.6645       778
#                            macro avg     0.4262    0.4262    0.4208       778
#                         weighted avg     0.6644    0.6645    0.6579       778
#
# [kannada-voting_ensemble] Errors saved → error_analysis/kannada_voting_ensemble_misclassified.csv (261 rows)
# [kannada-voting_ensemble] Confusion Matrix saved → error_analysis/kannada_voting_ensemble_confusion_matrix.png
#
# ===== KANNADA - WEIGHTED_ENSEMBLE =====
#
# KANNADA-WEIGHTED_ENSEMBLE | Test F1=0.4137, Acc=0.6517
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.7961    0.6768    0.7316       427
#      Offensive_Targeted_Insult_Group     0.3333    0.3182    0.3256        44
# Offensive_Targeted_Insult_Individual     0.5844    0.6000    0.5921        75
#      Offensive_Targeted_Insult_Other     0.0000    0.0000    0.0000        14
#                Offensive_Untargetede     0.1481    0.1212    0.1333        33
#                          not-Kannada     0.6008    0.8378    0.6998       185
#
#                             accuracy                         0.6517       778
#                            macro avg     0.4105    0.4257    0.4137       778
#                         weighted avg     0.6613    0.6517    0.6491       778
#
# [kannada-weighted_ensemble] Errors saved → error_analysis/kannada_weighted_ensemble_misclassified.csv (271 rows)
# [kannada-weighted_ensemble] Confusion Matrix saved → error_analysis/kannada_weighted_ensemble_confusion_matrix.png
#
# ===== MALAYALAM - VOTING_ENSEMBLE =====
#
# MALAYALAM-VOTING_ENSEMBLE | Test F1=0.6444, Acc=0.9275
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9635    0.9569    0.9602      1765
#      Offensive_Targeted_Insult_Group     0.6154    0.3478    0.4444        23
# Offensive_Targeted_Insult_Individual     0.8462    0.4074    0.5500        27
#                Offensive_Untargetede     0.4571    0.5517    0.5000        29
#                        not-malayalam     0.7059    0.8408    0.7674       157
#
#                             accuracy                         0.9275      2001
#                            macro avg     0.7176    0.6209    0.6444      2001
#                         weighted avg     0.9304    0.9275    0.9269      2001
#
# [malayalam-voting_ensemble] Errors saved → error_analysis/malayalam_voting_ensemble_misclassified.csv (145 rows)
# [malayalam-voting_ensemble] Confusion Matrix saved → error_analysis/malayalam_voting_ensemble_confusion_matrix.png
#
# ===== MALAYALAM - WEIGHTED_ENSEMBLE =====
#
# MALAYALAM-WEIGHTED_ENSEMBLE | Test F1=0.6921, Acc=0.9245
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9799    0.9382    0.9586      1765
#      Offensive_Targeted_Insult_Group     0.4545    0.4348    0.4444        23
# Offensive_Targeted_Insult_Individual     0.6552    0.7037    0.6786        27
#                Offensive_Untargetede     0.5000    0.7931    0.6133        29
#                        not-malayalam     0.6636    0.9045    0.7655       157
#
#                             accuracy                         0.9245      2001
#                            macro avg     0.6506    0.7549    0.6921      2001
#                         weighted avg     0.9377    0.9245    0.9288      2001
#
# [malayalam-weighted_ensemble] Errors saved → error_analysis/malayalam_weighted_ensemble_misclassified.csv (151 rows)
# [malayalam-weighted_ensemble] Confusion Matrix saved → error_analysis/malayalam_weighted_ensemble_confusion_matrix.png
#
# ===== TULU - VOTING_ENSEMBLE =====
#
# TULU-VOTING_ENSEMBLE | Test F1=0.7629, Acc=0.8073
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#        not offensive     0.7903    0.9074    0.8448       270
#             not tulu     0.8593    0.7484    0.8000       155
#   offensive targeted     0.8125    0.5000    0.6190        52
# offensive untargeted     0.7879    0.7879    0.7879        99
#
#             accuracy                         0.8073       576
#            macro avg     0.8125    0.7359    0.7629       576
#         weighted avg     0.8105    0.8073    0.8026       576
#
# [tulu-voting_ensemble] Errors saved → error_analysis/tulu_voting_ensemble_misclassified.csv (111 rows)
# [tulu-voting_ensemble] Confusion Matrix saved → error_analysis/tulu_voting_ensemble_confusion_matrix.png
#
# ===== TULU - WEIGHTED_ENSEMBLE =====
#
# TULU-WEIGHTED_ENSEMBLE | Test F1=0.7925, Acc=0.8247
# Classification Report (Test):
#                       precision    recall  f1-score   support
#
#        not offensive     0.8393    0.8704    0.8545       270
#             not tulu     0.8366    0.8258    0.8312       155
#   offensive targeted     0.7805    0.6154    0.6882        52
# offensive untargeted     0.7843    0.8081    0.7960        99
#
#             accuracy                         0.8247       576
#            macro avg     0.8102    0.7799    0.7925       576
#         weighted avg     0.8238    0.8247    0.8232       576
#
# [tulu-weighted_ensemble] Errors saved → error_analysis/tulu_weighted_ensemble_misclassified.csv (101 rows)
# [tulu-weighted_ensemble] Confusion Matrix saved → error_analysis/tulu_weighted_ensemble_confusion_matrix.png
#
# ===== TAMIL - VOTING_ENSEMBLE =====
#
# TAMIL-VOTING_ENSEMBLE | Test F1=0.4525, Acc=0.6997
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.8951    0.7969    0.8431      3190
#      Offensive_Targeted_Insult_Group     0.2604    0.3924    0.3130       288
# Offensive_Targeted_Insult_Individual     0.3359    0.4159    0.3716       315
#      Offensive_Targeted_Insult_Other     0.0909    0.0563    0.0696        71
#                Offensive_Untargetede     0.3090    0.4375    0.3622       368
#                            not-Tamil     0.7485    0.7625    0.7554       160
#
#                             accuracy                         0.6997      4392
#                            macro avg     0.4400    0.4769    0.4525      4392
#                         weighted avg     0.7459    0.6997    0.7185      4392
#
# [tamil-voting_ensemble] Errors saved → error_analysis/tamil_voting_ensemble_misclassified.csv (1319 rows)
# [tamil-voting_ensemble] Confusion Matrix saved → error_analysis/tamil_voting_ensemble_confusion_matrix.png
#
# ===== TAMIL - WEIGHTED_ENSEMBLE =====
#
# TAMIL-WEIGHTED_ENSEMBLE | Test F1=0.4481, Acc=0.6926
# Classification Report (Test):
#                                       precision    recall  f1-score   support
#
#                        Not_offensive     0.9063    0.7824    0.8398      3190
#      Offensive_Targeted_Insult_Group     0.2551    0.3889    0.3081       288
# Offensive_Targeted_Insult_Individual     0.3309    0.4381    0.3770       315
#      Offensive_Targeted_Insult_Other     0.0741    0.0563    0.0640        71
#                Offensive_Untargetede     0.3055    0.4565    0.3660       368
#                            not-Tamil     0.6966    0.7750    0.7337       160
#
#                             accuracy                         0.6926      4392
#                            macro avg     0.4281    0.4829    0.4481      4392
#                         weighted avg     0.7509    0.6926    0.7157      4392
#
# [tamil-weighted_ensemble] Errors saved → error_analysis/tamil_weighted_ensemble_misclassified.csv (1350 rows)
# [tamil-weighted_ensemble] Confusion Matrix saved → error_analysis/tamil_weighted_ensemble_confusion_matrix.png
